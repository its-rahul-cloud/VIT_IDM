# %%
# !rm -rf VIT_IDM
# !git clone https://github.com/its-rahul-cloud/VIT_IDM.git
# Out:
# Cloning into 'VIT_IDM'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 71 (delta 8), reused 69 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (71/71), 1.11 MiB | 10.33 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# !pip install xformers
# Out:
# Collecting xformers
#   Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xformers) (1.26.4)
# Collecting torch==2.5.1 (from xformers)
#   Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.5.1->xformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.5.1->xformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.5.1->xformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.5.1->xformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.1->xformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.1->xformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.1->xformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.1->xformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.1->xformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch==2.5.1->xformers)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch==2.5.1->xformers)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.1->xformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch==2.5.1->xformers)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->xformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->xformers) (3.0.2)
# Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 74.0 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 61.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 56.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.2 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.7 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 2.0 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, xformers
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.77
#     Uninstalling nvidia-nvjitlink-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.77
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.3.3
#     Uninstalling nvidia-cublas-cu12-12.6.3.3:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.3.3
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.5.1.17
#     Uninstalling nvidia-cudnn-cu12-9.5.1.17:
#       Successfully uninstalled nvidia-cudnn-cu12-9.5.1.17
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.0+cu121
#     Uninstalling torch-2.5.0+cu121:
#       Successfully uninstalled torch-2.5.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.0+cu121 requires torch==2.5.0, but you have torch 2.5.1 which is incompatible.
# torchvision 0.20.0+cu121 requires torch==2.5.0, but you have torch 2.5.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 torch-2.5.1 triton-3.1.0 xformers-0.0.28.post3

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import gdown
file_id="1twsjZ0kQkyFdfLcw8EYmvQmsRIgqnI3o"
gdrive_url=f'https://drive.google.com/uc?id={file_id}'
gdown.download(gdrive_url, 'TPD_240epochs.ckpt', quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1twsjZ0kQkyFdfLcw8EYmvQmsRIgqnI3o
# From (redirected): https://drive.google.com/uc?id=1twsjZ0kQkyFdfLcw8EYmvQmsRIgqnI3o&confirm=t&uuid=210966f8-c723-4206-b5d4-336040a71cfd
# To: /content/TPD_240epochs.ckpt
# 100%|██████████| 3.78G/3.78G [01:17<00:00, 48.6MB/s]
# 'TPD_240epochs.ckpt'

# %%
# !wget https://www.dropbox.com/scl/fi/xu08cx3fxmiwpg32yotd7/zalando-hd-resized.zip?rlkey=ks83mdv2pvmrdl2oo2bmmn69w&e=1&dl=0
# Out:
# --2024-11-11 04:49:22--  https://www.dropbox.com/scl/fi/xu08cx3fxmiwpg32yotd7/zalando-hd-resized.zip?rlkey=ks83mdv2pvmrdl2oo2bmmn69w
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://
1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)
# Downloading pyngrok-7.2.1-py3-none-any.whl (22 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.1
# Collecting flask_cors
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: Flask>=0.9 in /usr/local/lib/python3.10/dist-packages (from flask_cors) (2.2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->flask_cors) (3.0.6)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->flask_cors) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->flask_cors) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.9->flask_cors) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask>=0.9->flask_cors) (3.0.2)
# Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Installing collected packages: flask_cors
# Successfully installed flask_cors-5.0.0

# %%
# !pip -q install omegaconf==2.3.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.6 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
# !pip -q install pytorch-lightning==2.0.7
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.0/725.0 kB 44.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.4/891.4 kB 52.3 MB/s eta 0:00:00

# %%
# !pip -q install git+https://github.com/CompVis/latent-diffusion.git
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for latent-diffusion (setup.py) ... done

# %%
import sys
import os
sys.path.append(os.path.abspath('/content/VIT_IDM/VIT_IDM'))

# %%
# !pip install lightning-utilities==0.8.0
# Out:
# Collecting lightning-utilities==0.8.0
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from lightning-utilities==0.8.0) (24.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities==0.8.0) (4.12.2)
# Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Installing collected packages: lightning-utilities
#   Attempting uninstall: lightning-utilities
#     Found existing installation: lightning-utilities 0.11.8
#     Uninstalling lightning-utilities-0.11.8:
#       Successfully uninstalled lightning-utilities-0.11.8
# Successfully installed lightning-utilities-0.8.0

# %%
# !pip install taming-transformers
# Out:
# Collecting taming-transformers
#   Downloading taming_transformers-0.0.1-py3-none-any.whl.metadata (499 bytes)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (2.5.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (0.20.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (1.26.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (4.66.6)
# Requirement already satisfied: omegaconf>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (2.3.0)
# Requirement already satisfied: pytorch-lightning>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (2.0.7)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0.0->taming-transformers) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0.0->taming-transformers) (6.0.2)
# Requirement already satisfied: fsspec>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (2024.10.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers) (1.5.2)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers) (24.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->taming-transformers) (1.3.0)
# Collecting torch (from taming-transformers)
#   Downloading torch-2.5.0-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->taming-transformers) (10.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (3.10.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->taming-transformers) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (4.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (3.10)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (0.2.0)
# Downloading taming_transformers-0.0.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 4.2 MB/s eta 0:00:00
# Downloading torch-2.5.0-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.8 MB/s eta 0:00:00
# Installing collected packages: torch, taming-transformers
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1
#     Uninstalling torch-2.5.1:
#       Successfully uninstalled torch-2.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xformers 0.0.28.post3 requires torch==2.5.1, but you have torch 2.5.0 which is incompatible.
# Successfully installed taming-transformers-0.0.1 torch-2.5.0

# %%
# !pip install lpips==0.1.4
# Out:
# Collecting lpips==0.1.4
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (2.5.0)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (0.20.0+cu121)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (1.26.4)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (1.13.1)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (4.66.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=0.4.0->lpips==0.1.4) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.2.1->lpips==0.1.4) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.0->lpips==0.1.4) (3.0.2)
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: lpips
# Successfully installed lpips-0.1.4

# %%
# !pip install bezier
# Out:
# Collecting bezier
#   Downloading bezier-2024.6.20-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting numpy>=2.0.0 (from bezier)
#   Downloading numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.7 MB/s eta 0:00:00
# Downloading bezier-2024.6.20-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 67.9 MB/s eta 0:00:00
# Downloading numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 85.2 MB/s eta 0:00:00
# Installing collected packages: numpy, bezier
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cupy-cuda12x 12.2.0 requires numpy<1.27,>=1.20, but you have numpy 2.1.3 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.1.3 which is incompatible.
# langchain 0.3.4 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.1.3 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.1.3 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.3 which is incompatible.
# pytensor 2.25.5 requires numpy<2,>=1.17.0, but you have numpy 2.1.3 which is incompatible.
# tensorflow 2.17.0 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.1.3 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.1.3 which is incompatible.
# xformers 0.0.28.post3 requires torch==2.5.1, but you have torch 2.5.0 which is incompatible.
# Successfully installed bezier-2024.6.20 numpy-2.1.3

# %%
# !pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1+cu113 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.12.1+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.12.1%2Bcu113-cp310-cp310-linux_x86_64.whl (1837.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 570.5 kB/s eta 0:00:00
# Collecting torchvision==0.13.1+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.13.1%2Bcu113-cp310-cp310-linux_x86_64.whl (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 85.7 MB/s eta 0:00:00
# Collecting torchaudio==0.12.1+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.12.1%2Bcu113-cp310-cp310-linux_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 101.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.12.1+cu113) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.1+cu113) (2.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.1+cu113) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.1+cu113) (10.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1+cu113) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1+cu113) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1+cu113) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1+cu113) (2024.8.30)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.0
#     Uninstalling torch-2.5.0:
#       Successfully uninstalled torch-2.5.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.0+cu121
#     Uninstalling torchvision-0.20.0+cu121:
#       Successfully uninstalled torchvision-0.20.0+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.5.0+cu121
#     Uninstalling torchaudio-2.5.0+cu121:
#       Successfully uninstalled torchaudio-2.5.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.13.2 requires torch>=1.13.0, but you have torch 1.12.1+cu113 which is incompatible.
# xformers 0.0.28.post3 requires torch==2.5.1, but you have torch 1.12.1+cu113 which is incompatible.
# Successfully installed torch-1.12.1+cu113 torchaudio-0.12.1+cu113 torchvision-0.13.1+cu113

# %%
# !pip install absl-py==2.0.0 \
aiofiles==23.2.1 \
aiohttp==3.9.1 \
aiosignal==1.3.1 \
albumentations==1.3.0 \
altair==5.2.0 \
annotated-types==0.6.0 \
antlr4-python3-runtime==4.9.3 \
anyio==4.2.0 \
appdirs==1.4.4 \
async-timeout==4.0.3 \
attrs==23.1.0 \
beautifulsoup4==4.12.2 \
bitsandbytes==0.41.2.post2 \
black==24.1.1 \
blinker==1.7.0 \
blis==0.7.11 \
braceexpand==0.1.7 \
cachetools==5.3.2 \
catalogue==2.0.10 \
chardet==5.2.0 \
charset-normalizer==3.3.2 \
chumpy==0.70 \
click==8.1.7 \
cloudpathlib==0.16.0 \
cloudpickle==3.0.0 \
cmake==3.27.9 \
confection==0.1.4 \
contextlib2==21.6.0 \
contourpy==1.2.0 \
cycler==0.12.1 \
cymem==2.0.8 \
diffusers==0.24.0 \
docker-pycreds==0.4.0 \
einops==0.3.0 \
execnet==2.0.2 \
fastapi==0.109.0 \
fastrlock==0.8.2 \
ffmpy==0.3.1 \
filelock==3.13.1 \
fire==0.5.0 \
flatbuffers==23.5.26 \
fonttools==4.46.0 \
freetype-py==2.4.0 \
frozenlist==1.4.0 \
fsspec==2023.12.0 \
ftfy==6.1.3 \
future==0.18.3 \
fvcore==0.1.5.post20221221 \
gdown==4.7.1 \
gitdb==4.0.11 \
gitpython==3.1.40 \
google-auth==2.24.0 \
google-auth-oauthlib==1.1.0 \
gradio==3.16.2 \
grpcio==1.59.3 \
h11==0.14.0 \
h5py==3.10.0 \
httpcore==1.0.2 \
httpx==0.26.0 \
huggingface-hub>=0.15.1 \
hydra-core==1.3.2 \
idna==3.6 \
imageio==2.9.0 \
imageio-ffmpeg==0.4.2 \
importlib-metadata==7.0.0 \
importlib-resources==6.1.1 \
iniconfig==2.0.0 \
invisible-watermark==0.2.0 \
iopath==0.1.9 \
jinja2==3.1.2 \
joblib==1.3.2 \
jsonschema==4.20.0 \
jsonschema-specifications==2023.11.2 \
kiwisolver==1.4.5 \
kornia==0.6.0 \
langcodes==3.3.0 \
lazy-loader==0.3 \
linkify-it-py==2.0.2 \
lit==17.0.6 \
lpips==0.1.4 \
markdown==3.5.1 \
markdown-it-py==3.0.0 \
markupsafe==2.1.3 \
matplotlib==3.3.4 \
mdit-py-plugins==0.4.0 \
mdurl==0.1.2 \
mediapipe==0.10.8 \
mock==5.1.0 \
multidict==6.0.4 \
murmurhash==1.0.10 \
mypy-extensions==1.0.0 \
networkx==3.2.1 \
numpy==1.23.5 \
oauthlib==3.2.2 \
omegaconf==2.3.0 \
open-clip-torch==2.0.2 \
opencv-contrib-python==4.8.1.78 \
opencv-python==4.6.0.66 \
opencv-python-headless==4.8.1.78 \
orjson==3.9.12 \
pandas==2.1.3 \
path==16.9.0 \
path-py==12.5.0 \
pathspec==0.12.1 \
pexpect==4.9.0 \
pillow==9.5.0 \
pluggy==1.3.0 \
portalocker==2.8.2 \
preshed==3.0.9 \
prompt-toolkit==3.0.43 \
protobuf==3.20.3 \
psutil==5.9.6 \
pyarrow==14.0.1 \
pyasn1==0.5.1 \
pyasn1-modules==0.3.0 \
pycocotools==2.0.7 \
pycryptodome==3.20.0 \
pydantic==2.5.2 \
pydantic-core==2.14.5 \
pydeck==0.8.1b0 \
pydeprecate==0.3.1 \
pydub==0.25.1 \
pyglet==2.0.10 \
pympler==1.0.1 \
pyopengl==3.1.0 \
pyparsing==3.1.1 \
pyrender==0.1.45 \
pytest==7.4.3 \
pytest-shutil==1.7.0 \
python-multipart==0.0.6 \
pytorch-fid==0.3.0 \
pytorch-lightning==1.4.2 \
pytz==2023.3.post1 \
pywavelets==1.5.0 \
pyyaml==6.0.1 \
qudida==0.0.4 \
referencing==0.31.1 \
regex==2023.10.3 \
requests-oauthlib==1.3.1 \
rich==13.7.0 \
rpds-py==0.13.2 \
rsa==4.9 \
safetensors==0.4.1 \
scikit-image==0.20.0 \
scikit-learn==1.3.2 \
scipy==1.9.1 \
semver==3.0.2 \
sentry-sdk==1.38.0 \
setproctitle==1.3.3 \
smart-open==6.4.0 \
smmap==5.0.1 \
smplx==0.1.28 \
sniffio==1.3.0 \
sounddevice==0.4.6 \
soupsieve==2.5 \
spacy==3.7.2 \
spacy-legacy==3.0.12 \
spacy-loggers==1.0.5 \
srsly==2.4.8 \
stack-data==0.6.3 \
starlette==0.35.1 \
streamlit==1.12.1 \
streamlit-drawable-canvas==0.8.0 \
tabulate==0.9.0 \
tensorboard==2.15.1 \
tensorboard-data-server==0.7.2 \
termcolor==2.4.0 \
test-tube==0.7.5 \
thinc==8.2.1 \
threadpoolctl==3.2.0 \
tifffile==2023.9.26 \
tokenizers==0.13.3 \
toml==0.10.2 \
tomli==2.0.1 \
toolz==0.12.0 \
torchmetrics==0.6.0 \
tornado==6.4 \
tqdm==4.66.1 \
transformers==4.32.1 \
trimesh==4.0.5 \
triton==2.0.0 \
typer==0.9.0 \
tzdata==2023.3 \
tzlocal==5.2 \
uc-micro-py==1.0.2 \
urllib3==2.1.0 \
uvicorn==0.27.0 \
validators==0.22.0 \
wandb==0.16.0 \
wasabi==1.1.2 \
watchdog==3.0.0 \
weasel==0.3.4 \
webdataset==0.2.5 \
websockets==12.0 \
werkzeug==3.0.1 \
yacs==0.1.8 \
yarl==1.9.3 \
zipp==3.17.0
# Out:
# error: uninstall-distutils-installed-package
#
# × Cannot uninstall blinker 1.4
# ╰─> It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
# !pip install pydantic==2.7.0
# !pip install pydantic_core==2.18.1
# Out:
# Collecting pydantic==2.7.0
#   Downloading pydantic-2.7.0-py3-none-any.whl.metadata (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.7.0) (0.7.0)
# Collecting pydantic-core==2.18.1 (from pydantic==2.7.0)
#   Downloading pydantic_core-2.18.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.7.0) (4.12.2)
# Downloading pydantic-2.7.0-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.9/407.9 kB 28.4 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 72.1 MB/s eta 0:00:00
# Installing collected packages: pydantic-core, pydantic
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.5
#     Uninstalling pydantic_core-2.14.5:
#       Successfully uninstalled pydantic_core-2.14.5
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# langchain 0.3.4 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 2.7.0 which is incompatible.
# langsmith 0.1.137 requires orjson<4.0.0,>=3.9.14, but you have orjson 3.9.12 which is incompatible.
# Successfully installed pydantic-2.7.0 pydantic-core-2.18.1
# Requirement already satisfied: pydantic_core==2.18.1 in /usr/local/lib/python3.10/dist-packages (2.18.1)
# Requirement already satisfied: typing-extensions!=4.7.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic_core==2.18.1) (4.12.2)

# %%
# !pip install -U safetensors
# Out:
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (0.4.1)
# Collecting safetensors
#   Downloading safetensors-0.4.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Downloading safetensors-0.4.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.0/435.0 kB 21.8 MB/s eta 0:00:00
# Installing collected packages: safetensors
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.4.1
#     Uninstalling safetensors-0.4.1:
#       Successfully uninstalled safetensors-0.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.13.2 requires torch>=1.13.0, but you have torch 1.12.1+cu113 which is incompatible.
# transformers 4.44.2 requires tokenizers<0.20,>=0.19, but you have tokenizers 0.13.3 which is incompatible.
# Successfully installed safetensors-0.4.5

# %%
# !pip install git+https://github.com/CompVis/latent-diffusion.git
# Out:
# Collecting git+https://github.com/CompVis/latent-diffusion.git
#   Cloning https://github.com/CompVis/latent-diffusion.git to /tmp/pip-req-build-hdzd51d0
#   Running command git clone --filter=blob:none --quiet https://github.com/CompVis/latent-diffusion.git /tmp/pip-req-build-hdzd51d0
#   Resolved https://github.com/CompVis/latent-diffusion.git to commit a506df5756472e2ebaf9078affdde2c4f1502cd4
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from latent-diffusion==0.0.1) (1.12.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from latent-diffusion==0.0.1) (1.23.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from latent-diffusion==0.0.1) (4.66.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->latent-diffusion==0.0.1) (4.12.2)

# %%
import sys
sys.path.append('/content/VIT_IDM/VIT_IDM')

# %%
# import os
# from flask import Flask, request, send_file, jsonify, send_from_directory
# from flask_cors import CORS
# from werkzeug.utils import secure_filename
# from pyngrok import ngrok
# from scripts.inference import main
# import shutil

# # Directories for body and cloth images
# body_image_dir = "/content/VIT_IDM/VIT_IDM/datasets/VITONHD/test/image"
# cloth_image_dir = "/content/VIT_IDM/VIT_IDM/datasets/VITONHD/test/cloth"
# result_dir = "/content/VIT_IDM/VIT_IDM/datasets/VITONHD/test/results"

# # Ensure directories exist
# # os.makedirs(body_image_dir, exist_ok=True)
# # os.makedirs(cloth_image_dir, exist_ok=True)
# # os.makedirs(result_dir, exist_ok=True)

# app = Flask(__name__)

# # Enable CORS for all routes with specific origin (i.e., the frontend's URL)
# CORS(app, resources={r"/*": {"origins": "https://h2e3.top"}})

# # Set up Ngrok tunnel
# ngrok.set_auth_token('2oeGUPKJRWRsm81p7cLeoEWYCAY_Gi1zfxM9dd9CJUTpkWZ7')
# public_url = ngrok.connect(5000).public_url
# print(f"Public URL: {public_url}")

# @app.route("/hello", methods=["GET"])
# def hello():
#     """Simple endpoint to check if the server is live."""
#     return "yes", 200

# @app.route("/list_images", methods=["GET"])
# def list_images():
#     """Lists all files in the body and cloth directories."""
#     body_images = os.listdir(body_image_dir)
#     cloth_images = os.listdir(cloth_image_dir)
#     return jsonify({"body_images": body_images, "cloth_images": cloth_images})

# # Endpoint to serve a specific body image
# @app.route('/image/<filename>', methods=['GET'])
# def get_body_image(filename):
#     return send_from_directory(body_image_dir, filename, mimetype='image/jpeg')

# # Endpoint to serve a specific cloth image
# @app.route('/cloth/<filename>', methods=['GET'])
# def get_cloth_image(filename):
#     return send_from_directory(cloth_image_dir, filename, mimetype='image/jpeg')

# @app.route("/upload/<image_type>", methods=["POST"])
# def upload_image(image_type):
#     """Upload a new image."""
#     if image_type not in ["body", "cloth"]:
#         return jsonify({"error": "Invalid image type"}), 400

#     if 'file' not in request.files:
#         return jsonify({"error": "No file provided"}), 400

#     file = request.files['file']
#     filename = secure_filename(file.filename)
#     directory = body_image_dir if image_type == "body" else cloth_image_dir
#     file_path = os.path.join(directory, filename)
#     file.save(file_path)

#     return jsonify({"message": f"File '{filename}' uploaded successfully", "filename": filename})


# import os
# import shutil
# from flask import request, jsonify

# @app.route("/merge_images", methods=["POST"])
# def merge_images():
#     """Merges selected body and cloth images."""
#     data = request.json
#     body_image = data.get("body_image")
#     cloth_image = data.get("cloth_image")

#     # Define the directories for body and cloth images
#     body_image_dir = "/content/VIT_IDM/VIT_IDM/datasets/VITONHD/test/agnostic-v3.2"
#     cloth_image_dir = "/content/VIT_IDM/VIT_IDM/datasets/VITONHD/test/cloth-mask"
#     paired_txt_path = "/content/VIT_IDM/VIT_IDM/datasets/VITONHD/VITONHD_test_paired.txt"

#     # Check if the body and cloth images exist in their respective directories
#     body_image_path = os.path.join(body_image_dir, body_image)
#     cloth_image_path = os.path.join(cloth_image_dir, cloth_image)

#     if not os.path.exists(body_image_path):
#         return jsonify({"error": f"Body image '{body_image}' not found in {body_image_dir}"}), 404
#     if not os.path.exists(cloth_image_path):
#         return jsonify({"error": f"Cloth image '{cloth_image}' not found in {cloth_image_dir}"}), 404

#     # If both images exist, rewrite the txt file with the body and cloth image names
#     try:
#         with open(paired_txt_path, "w") as f:  # Open file in write mode to overwrite
#             f.write(f"{body_image} {cloth_image}\n")
#     except Exception as e:
#         return jsonify({"error": f"Failed to write to paired text file: {str(e)}"}), 500

#     # Simulate a merging process (replace with actual model code)
#     # result_path = os.path.join(result_dir, f"{body_image}")  # Placeholder result path

#     # Placeholder for actual merging logic. For now, just copying the body image to the result directory.
#     # shutil.copy(body_image_path, result_path)
#     main()
#     return jsonify({"message": "Images merged successfully", "result_image": body_image})



# @app.route("/results/<stage>/<filename>", methods=["GET"])
# def get_result(filename):
#     """Retrieve merged result image."""
#     result_path = os.path.join(result_dir, filename)
#     if os.path.exists(result_path):
#         return send_from_directory(result_dir, filename, mimetype='image/jpeg')
#     return jsonify({"error": "Result file not found"}), 404

# # Start the Flask app
# if __name__ == "__main__":
#     app.run(port=5000)

# %%
# !pip install -U xformers --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: xformers in /usr/local/lib/python3.10/dist-packages (0.0.28.post3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xformers) (1.23.5)
# Collecting torch==2.5.1 (from xformers)
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.5.1%2Bcu118-cp310-cp310-linux_x86_64.whl (838.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 838.3/838.3 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (2023.12.0)
# Collecting nvidia-cuda-nvrtc-cu11==11.8.89 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 78.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.8.89 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (875 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 55.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.8.87 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux1_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 112.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==9.1.0.70 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cudnn_cu11-9.1.0.70-py3-none-manylinux2014_x86_64.whl (663.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 1.7 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.11.3.6 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux1_x86_64.whl (417.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 4.1 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.8 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.3.0.86 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_curand_cu11-10.3.0.86-py3-none-manylinux1_x86_64.whl (58.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 14.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.1.48 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux1_x86_64.whl (128.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 7.9 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.5.86 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux1_x86_64.whl (204.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 5.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.21.5 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nccl_cu11-2.21.5-py3-none-manylinux2014_x86_64.whl (147.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 7.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.8.86 (from torch==2.5.1->xformers)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nvtx_cu11-11.8.86-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->xformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->xformers) (2.1.3)
# Installing collected packages: nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 2.5.1+cu118 which is incompatible.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 2.5.1+cu118 which is incompatible.
# Successfully installed nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-cupti-cu11-11.8.87 nvidia-cuda-nvrtc-cu11-11.8.89 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cudnn-cu11-9.1.0.70 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.3.0.86 nvidia-cusolver-cu11-11.4.1.48 nvidia-cusparse-cu11-11.7.5.86 nvidia-nccl-cu11-2.21.5 nvidia-nvtx-cu11-11.8.86 torch-2.5.1+cu118

# %%
# %cd /content/VIT_IDM/VIT_IDM
# Out:
# /content/VIT_IDM/VIT_IDM

# %%
# !CUDA_VISIBLE_DEVICES=0 python /content/VIT_IDM/VIT_IDM/scripts/inference.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# ['/content/VIT_IDM/VIT_IDM/', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/setuptools/_vendor', '/tmp/tmpckaofwed']
# Global seed set to 321
# Loading model from /content/TPD_240epochs.ckpt
# /content/VIT_IDM/VIT_IDM/scripts/inference.py:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pl_sd = torch.load(ckpt, map_location="cpu")
# Global Step: 23360
# LatentDiffusion: Running in eps-prediction mode
# Setting up CrossAttention. Query dim is 320, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 320, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 320, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 320, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 640, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 640, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 640, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 640, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 1280, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 640, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 640, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 640, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 640, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 640, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 640, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 320, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 320, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 320, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 320, context_dim is 768 and using 8 heads.
# Setting up CrossAttention. Query dim is 320, context_dim is None and using 8 heads.
# Setting up CrossAttention. Query dim is 320, context_dim is 768 and using 8 heads.
# DiffusionWrapper has 859.56 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# test Dataset:   0% 0/1 [00:00<?, ?it/s]Data shape for DDIM sampling is (1, 5, 64, 96), eta 0.0
# Running DDIM Sampling with 100 timesteps
#
# DDIM Sampler:   0% 0/100 [00:00<?, ?it/s]
# DDIM Sampler:   1% 1/100 [00:00<00:40,  2.45it/s]
# DDIM Sampler:   2% 2/100 [00:00<00:24,  3.95it/s]
# DDIM Sampler:   3% 3/100 [00:00<00:19,  4.85it/s]
# DDIM Sampler:   4% 4/100 [00:00<00:17,  5.44it/s]
# DDIM Sampler:   5% 5/100 [00:01<00:16,  5.84it/s]
# DDIM Sampler:   6% 6/100 [00:01<00:15,  6.08it/s]
# DDIM Sampler:   7% 7/100 [00:01<00:15,  6.17it/s]
# DDIM Sampler:   8% 8/100 [00:01<00:14,  6.28it/s]
# DDIM Sampler:   9% 9/100 [00:01<00:14,  6.40it/s]
# DDIM Sampler:  10% 10/100 [00:01<00:13,  6.48it/s]
# DDIM Sampler:  11% 11/100 [00:01<00:13,  6.53it/s]
# DDIM Sampler:  12% 12/100 [00:02<00:13,  6.56it/s]
# DDIM Sampler:  13% 13/100 [00:02<00:13,  6.59it/s]
# DDIM Sampler:  14% 14/100 [00:02<00:13,  6.55it/s]
# DDIM Sampler:  15% 15/100 [00:02<00:12,  6.57it/s]
# DDIM Sampler:  16% 16/100 [00:02<00:12,  6.59it/s]
# DDIM Sampler:  17% 17/100 [00:02<00:12,  6.60it/s]
# DDIM Sampler:  18% 18/100 [00:02<00:12,  6.62it/s]
# DDIM Sampler:  19% 19/100 [00:03<00:12,  6.62it/s]
# DDIM Sampler:  20% 20/100 [00:03<00:12,  6.63it/s]
# DDIM Sampler:  21% 21/100 [00:03<00:11,  6.61it/s]
# DDIM Sampler:  22% 22/100 [00:03<00:11,  6.60it/s]
# DDIM Sampler:  23% 23/100 [00:03<00:11,  6.57it/s]
# DDIM Sampler:  24% 24/100 [00:03<00:11,  6.59it/s]
# DDIM Sampler:  25% 25/100 [00:04<00:11,  6.57it/s]
# DDIM Sampler:  26% 26/100 [00:04<00:11,  6.59it/s]
# DDIM Sampler:  27% 27/100 [00:04<00:11,  6.59it/s]
# DDIM Sampler:  28% 28/100 [00:04<00:10,  6.61it/s]
# DDIM Sampler:  29% 29/100 [00:04<00:10,  6.58it/s]
# DDIM Sampler:  30% 30/100 [00:04<00:10,  6.59it/s]
# DDIM Sampler:  31% 31/100 [00:04<00:10,  6.57it/s]
# DDIM Sampler:  32% 32/100 [00:05<00:10,  6.58it/s]
# DDIM Sampler:  33% 33/100 [00:05<00:10,  6.57it/s]
# DDIM Sampler:  34% 34/100 [00:05<00:10,  6.56it/s]
# DDIM Sampler:  35% 35/100 [00:05<00:09,  6.55it/s]
# DDIM Sampler:  36% 36/100 [00:05<00:09,  6.58it/s]
# DDIM Sampler:  37% 37/100 [00:05<00:09,  6.57it/s]
TTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:34:30] "OPTIONS /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:34:31] "OPTIONS /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:34:31] "GET /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:34:32] "GET /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:01] "OPTIONS /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:01] "OPTIONS /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:01] "GET /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:02] "GET /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:02] "OPTIONS /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:03] "OPTIONS /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:03] "GET /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:03] "GET /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:16] "OPTIONS /image/02663_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:16] "GET /image/02663_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:24] "OPTIONS /cloth/01026_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:25] "GET /cloth/01026_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:40:57] "OPTIONS /merge_images HTTP/1.1" 200 -
# test Dataset:   0% 0/1 [00:00<?, ?it/s]Data shape for DDIM sampling is (1, 5, 64, 96), eta 0.0
# Running DDIM Sampling with 100 timesteps
#
# DDIM Sampler:   0% 0/100 [00:00<?, ?it/s]
# DDIM Sampler:   1% 1/100 [00:00<00:16,  6.18it/s]
# DDIM Sampler:   2% 2/100 [00:00<00:15,  6.30it/s]
# DDIM Sampler:   3% 3/100 [00:00<00:15,  6.37it/s]
# DDIM Sampler:   4% 4/100 [00:00<00:15,  6.32it/s]
# DDIM Sampler:   5% 5/100 [00:00<00:14,  6.34it/s]
# DDIM Sampler:   6% 6/100 [00:00<00:14,  6.33it/s]
# DDIM Sampler:   7% 7/100 [00:01<00:14,  6.34it/s]
# DDIM Sampler:   8% 8/100 [00:01<00:14,  6.38it/s]
# DDIM Sampler:   9% 9/100 [00:01<00:14,  6.39it/s]
# DDIM Sampler:  10% 10/100 [00:01<00:14,  6.37it/s]
# DDIM Sampler:  11% 11/100 [00:01<00:14,  6.35it/s]
# DDIM Sampler:  12% 12/100 [00:01<00:13,  6.35it/s]
# DDIM Sampler:  13% 13/100 [00:02<00:13,  6.36it/s]
# DDIM Sampler:  14% 14/100 [00:02<00:13,  6.36it/s]
# DDIM Sampler:  15% 15/100 [00:02<00:13,  6.39it/s]
# DDIM Sampler:  16% 16/100 [00:02<00:13,  6.36it/s]
# DDIM Sampler:  17% 17/100 [00:02<00:13,  6.35it/s]
# DDIM Sampler:  18% 18/100 [00:02<00:12,  6.33it/s]
# DDIM Sampler:  19% 19/100 [00:02<00:12,  6.31it/s]
# DDIM Sampler:  20% 20/100 [00:03<00:12,  6.35it/s]
# DDIM Sampler:  21% 21/100 [00:03<00:12,  6.36it/s]
# DDIM Sampler:  22% 22/100 [00:03<00:12,  6.35it/s]
# DDIM Sampler:  23% 23/100 [00:03<00:12,  6.33it/s]
# DDIM Sampler:  24% 24/100 [00:03<00:12,  6.31it/s]
# DDIM Sampler:  25% 25/100 [00:03<00:11,  6.30it/s]
# DDIM Sampler:  26% 26/100 [00:04<00:11,  6.33it/s]
# DDIM Sampler:  27% 27/100 [00:04<00:11,  6.33it/s]
# DDIM Sampler:  28% 28/100 [00:04<00:11,  6.34it/s]
# DDIM Sampler:  29% 29/100 [00:04<00:11,  6.33it/s]
# DDIM Sampler:  30% 30/100 [00:04<00:11,  6.33it/s]
# DDIM Sampler:  31% 31/100 [00:04<00:10,  6.32it/s]
# DDIM Sampler:  32% 32/100 [00:05<00:10,  6.32it/s]
TTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:41:42] "OPTIONS /results/first_stage/02663_00.jpg HTTP/1.1" 200 -
# /content/inference_logs/VITONHD/VITONHD_release_input_person_combine_garment_240epochs_paired/result/first_stage/result
# 127.0.0.1 - - [10/Nov/2024 18:41:43] "GET /results/first_stage/02663_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:41:44] "OPTIONS /results/second_stage/02663_00.jpg HTTP/1.1" 200 -
# /content/inference_logs/VITONHD/VITONHD_release_input_person_combine_garment_240epochs_paired/result/second_stage/result
# 127.0.0.1 - - [10/Nov/2024 18:41:45] "GET /results/second_stage/02663_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:25] "POST /upload/body HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:28] "OPTIONS /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:28] "GET /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:56] "OPTIONS /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:56] "OPTIONS /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:56] "GET /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:57] "GET /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:57] "OPTIONS /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:58] "OPTIONS /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:58] "GET /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:43:58] "GET /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:44:38] "POST /upload/body HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:44:41] "OPTIONS /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:44:42] "GET /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:44:55] "OPTIONS /image/02663_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:44:55] "GET /image/02663_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:01] "OPTIONS /cloth/00401_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:02] "GET /cloth/00401_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:10] "OPTIONS /cloth/00583_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:11] "GET /cloth/00583_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:21] "OPTIONS /cloth/00790_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:21] "GET /cloth/00790_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:27] "OPTIONS /cloth/00960_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:28] "GET /cloth/00960_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:34] "OPTIONS /cloth/01248_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:34] "GET /cloth/01248_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:45:47] "OPTIONS /merge_images HTTP/1.1" 200 -
# test Dataset:   0% 0/1 [00:00<?, ?it/s]Data shape for DDIM sampling is (1, 5, 64, 96), eta 0.0
# Running DDIM Sampling with 100 timesteps
#
# DDIM Sampler:   0% 0/100 [00:00<?, ?it/s]
# DDIM Sampler:   1% 1/100 [00:00<00:17,  5.79it/s]
# DDIM Sampler:   2% 2/100 [00:00<00:16,  5.89it/s]
# DDIM Sampler:   3% 3/100 [00:00<00:16,  5.95it/s]
# DDIM Sampler:   4% 4/100 [00:00<00:16,  5.84it/s]
# DDIM Sampler:   5% 5/100 [00:00<00:16,  5.88it/s]
# DDIM Sampler:   6% 6/100 [00:01<00:15,  5.90it/s]
# DDIM Sampler:   7% 7/100 [00:01<00:15,  5.92it/s]
# DDIM Sampler:   8% 8/100 [00:01<00:15,  5.94it/s]
# DDIM Sampler:   9% 9/100 [00:01<00:15,  5.95it/s]
# DDIM Sampler:  10% 10/100 [00:01<00:15,  5.89it/s]
# DDIM Sampler:  11% 11/100 [00:01<00:15,  5.89it/s]
# DDIM Sampler:  12% 12/100 [00:02<00:14,  5.89it/s]
# DDIM Sampler:  13% 13/100 [00:02<00:14,  5.89it/s]
# DDIM Sampler:  14% 14/100 [00:02<00:14,  5.91it/s]
# DDIM Sampler:  15% 15/100 [00:02<00:14,  5.91it/s]
# DDIM Sampler:  86% 86/100 [00:14<00:02,  5.85it/s]
# DDIM Sampler:  87% 87/100 [00:15<00:02,  5.86it/s]
# DDIM Sampler:  88% 88/100 [00:15<00:02,  5.88it/s]
# DDIM Sampler:  89% 89/100 [00:15<00:01,  5.86it/s]
# DDIM Sampler:  90% 90/100 [00:15<00:01,  5.87it/s]
# DDIM Sampler:  91% 91/100 [00:15<00:01,  5.87it/s]
# DDIM Sampler:  92% 92/100 [00:15<00:01,  5.87it/s]
# DDIM Sampler:  93% 93/100 [00:16<00:01,  5.87it/s]
# DDIM Sampler:  94% 94/100 [00:16<00:01,  5.85it/s]
# DDIM Sampler:  95% 95/100 [00:16<00:00,  5.84it/s]
# DDIM Sampler:  96% 96/100 [00:16<00:00,  5.85it/s]
# DDIM Sampler:  97% 97/100 [00:16<00:00,  5.88it/s]
# DDIM Sampler:  98% 98/100 [00:16<00:00,  5.89it/s]
# DDIM Sampler:  99% 99/100 [00:17<00:00,  5.88it/s]
# DDIM Sampler: 100% 100/100 [00:17<00:00,  5.81it/s]
# test Dataset: 100% 1/1 [00:37<00:00, 37.26s/it]
# Your samples are ready and waiting for you here:
# /content/inference_logs/VITONHD/VITONHD_release_input_person_combine_garment_240epochs_paired/result
#
# Enjoy.
# 127.0.0.1 - - [10/Nov/2024 18:46:25] "POST /merge_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:46:29] "OPTIONS /results/first_stage/02663_00.jpg HTTP/1.1" 200 -
# /content/inference_logs/VITONHD/VITONHD_release_input_person_combine_garment_240epochs_paired/result/first_stage/result
# 127.0.0.1 - - [10/Nov/2024 18:46:29] "GET /results/first_stage/02663_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:46:30] "OPTIONS /results/second_stage/02663_00.jpg HTTP/1.1" 200 -
# /content/inference_logs/VITONHD/VITONHD_release_input_person_combine_garment_240epochs_paired/result/second_stage/result
# 127.0.0.1 - - [10/Nov/2024 18:46:31] "GET /results/second_stage/02663_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:51:32] "OPTIONS /image/03349_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:51:32] "GET /image/03349_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:51:38] "OPTIONS /cloth/02336_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:51:38] "GET /cloth/02336_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:52:22] "POST /upload/body HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:52:24] "OPTIONS /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:52:24] "GET /list_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:52:33] "OPTIONS /image/01670_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:52:34] "GET /image/01670_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:52:45] "OPTIONS /cloth/01123_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:52:46] "GET /cloth/01123_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:52:56] "OPTIONS /cloth/01048_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:52:56] "GET /cloth/01048_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:53:03] "OPTIONS /cloth/01188_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:53:04] "GET /cloth/01188_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:54:54] "OPTIONS /merge_images HTTP/1.1" 200 -
# test Dataset:   0% 0/1 [00:00<?, ?it/s]Data shape for DDIM sampling is (1, 5, 64, 96), eta 0.0
# Running DDIM Sampling with 100 timesteps
#
# DDIM Sampler:   0% 0/100 [00:00<?, ?it/s]
# DDIM Sampler:   1% 1/100 [00:00<00:16,  5.83it/s]
# DDIM Sampler:   2% 2/100 [00:00<00:16,  5.93it/s]
# DDIM Sampler:   3% 3/100 [00:00<00:16,  5.86it/s]
# DDIM Sampler:   4% 4/100 [00:00<00:16,  5.84it/s]
# DDIM Sampler:  91% 91/100 [00:15<00:01,  5.80it/s]
# DDIM Sampler:  92% 92/100 [00:15<00:01,  5.80it/s]
# DDIM Sampler:  93% 93/100 [00:15<00:01,  5.79it/s]
# DDIM Sampler:  94% 94/100 [00:16<00:01,  5.79it/s]
# DDIM Sampler:  95% 95/100 [00:16<00:00,  5.77it/s]
# DDIM Sampler:  96% 96/100 [00:16<00:00,  5.79it/s]
# DDIM Sampler:  97% 97/100 [00:16<00:00,  5.75it/s]
# DDIM Sampler:  98% 98/100 [00:16<00:00,  5.78it/s]
# DDIM Sampler:  99% 99/100 [00:16<00:00,  5.77it/s]
# DDIM Sampler: 100% 100/100 [00:17<00:00,  5.85it/s]
# Data shape for DDIM sampling is (1, 5, 64, 96), eta 0.0
# Running DDIM Sampling with 100 timesteps
#
# DDIM Sampler:   0% 0/100 [00:00<?, ?it/s]
# DDIM Sampler:   1% 1/100 [00:00<00:17,  5.78it/s]
# DDIM Sampler:   2% 2/100 [00:00<00:16,  5.79it/s]
# DDIM Sampler:   3% 3/100 [00:00<00:16,  5.81it/s]
# DDIM Sampler:   4% 4/100 [00:00<00:17,  5.61it/s]
# DDIM Sampler:   5% 5/100 [00:00<00:16,  5.62it/s]
# DDIM Sampler:   6% 6/100 [00:01<00:16,  5.69it/s]
# DDIM Sampler:   7% 7/100 [00:01<00:16,  5.75it/s]
# DDIM Sampler:   8% 8/100 [00:01<00:15,  5.77it/s]
# DDIM Sampler:   9% 9/100 [00:01<00:15,  5.79it/s]
# DDIM Sampler:  10% 10/100 [00:01<00:15,  5.73it/s]
# DDIM Sampler:  11% 11/100 [00:01<00:15,  5.75it/s]
# DDIM Sampler:  12% 12/100 [00:02<00:15,  5.75it/s]
# DDIM Sampler:  13% 13/100 [00:02<00:15,  5.78it/s]
# DDIM Sampler:  14% 14/100 [00:02<00:14,  5.79it/s]
# DDIM Sampler:  15% 15/100 [00:02<00:14,  5.79it/s]
# DDIM Sampler:  16% 16/100 [00:02<00:14,  5.76it/s]
# DDIM Sampler:  17% 17/100 [00:02<00:14,  5.78it/s]
# DDIM Sampler:  18% 18/100 [00:03<00:14,  5.80it/s]
# DDIM Sampler:  19% 19/100 [00:03<00:13,  5.81it/s]
# DDIM Sampler:  20% 20/100 [00:03<00:13,  5.82it/s]
# DDIM Sampler:  21% 21/100 [00:03<00:13,  5.81it/s]
# DDIM Sampler:  22% 22/100 [00:03<00:13,  5.80it/s]
# DDIM Sampler:  23% 23/100 [00:03<00:13,  5.81it/s]
# DDIM Sampler:  24% 24/100 [00:04<00:13,  5.82it/s]
# DDIM Sampler:  25% 25/100 [00:04<00:12,  5.84it/s]
# DDIM Sampler:  26% 26/100 [00:04<00:12,  5.83it/s]
# DDIM Sampler:  27% 27/100 [00:04<00:12,  5.83it/s]
# DDIM Sampler:  28% 28/100 [00:04<00:12,  5.82it/s]
# DDIM Sampler:  29% 29/100 [00:05<00:12,  5.82it/s]
# DDIM Sampler:  30% 30/100 [00:05<00:12,  5.82it/s]
# DDIM Sampler:  74% 74/100 [00:12<00:04,  5.86it/s]
# DDIM Sampler:  75% 75/100 [00:12<00:04,  5.86it/s]
# DDIM Sampler:  76% 76/100 [00:13<00:04,  5.85it/s]
# DDIM Sampler:  77% 77/100 [00:13<00:03,  5.85it/s]
# DDIM Sampler:  78% 78/100 [00:13<00:03,  5.86it/s]
# DDIM Sampler:  79% 79/100 [00:13<00:03,  5.88it/s]
# DDIM Sampler:  80% 80/100 [00:13<00:03,  5.87it/s]
# DDIM Sampler:  81% 81/100 [00:13<00:03,  5.88it/s]
# DDIM Sampler:  82% 82/100 [00:14<00:03,  5.87it/s]
# DDIM Sampler:  83% 83/100 [00:14<00:02,  5.89it/s]
# DDIM Sampler:  84% 84/100 [00:14<00:02,  5.88it/s]
# DDIM Sampler:  85% 85/100 [00:14<00:02,  5.87it/s]
# DDIM Sampler:  86% 86/100 [00:14<00:02,  5.88it/s]
# DDIM Sampler:  87% 87/100 [00:14<00:02,  5.87it/s]
# DDIM Sampler:  88% 88/100 [00:15<00:02,  5.88it/s]
# DDIM Sampler:  89% 89/100 [00:15<00:01,  5.88it/s]
# DDIM Sampler:  90% 90/100 [00:15<00:01,  5.88it/s]
# DDIM Sampler:  91% 91/100 [00:15<00:01,  5.88it/s]
# DDIM Sampler:  92% 92/100 [00:15<00:01,  5.87it/s]
# DDIM Sampler:  93% 93/100 [00:15<00:01,  5.89it/s]
# DDIM Sampler:  94% 94/100 [00:16<00:01,  5.87it/s]
# DDIM Sampler:  95% 95/100 [00:16<00:00,  5.89it/s]
# DDIM Sampler:  96% 96/100 [00:16<00:00,  5.88it/s]
# DDIM Sampler:  97% 97/100 [00:16<00:00,  5.89it/s]
# DDIM Sampler:  98% 98/100 [00:16<00:00,  5.87it/s]
# DDIM Sampler:  99% 99/100 [00:16<00:00,  5.88it/s]
# DDIM Sampler: 100% 100/100 [00:17<00:00,  5.83it/s]
# test Dataset: 100% 1/1 [00:37<00:00, 37.54s/it]
# Your samples are ready and waiting for you here:
# /content/inference_logs/VITONHD/VITONHD_release_input_person_combine_garment_240epochs_paired/result
#
# Enjoy.
# 127.0.0.1 - - [10/Nov/2024 18:55:32] "POST /merge_images HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:55:44] "OPTIONS /results/first_stage/01670_00.jpg HTTP/1.1" 200 -
# /content/inference_logs/VITONHD/VITONHD_release_input_person_combine_garment_240epochs_paired/result/first_stage/result
# 127.0.0.1 - - [10/Nov/2024 18:55:45] "GET /results/first_stage/01670_00.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2024 18:55:45] "OPTIONS /results/second_stage/01670_00.jpg HTTP/1.1" 200 -
# /content/inference_logs/VITONHD/VITONHD_release_input_person_combine_garment_240epochs_paired/result/second_stage/result
# 127.0.0.1 - - [10/Nov/2024 18:55:46] "GET /results/second_stage/01670_00.jpg HTTP/1.1" 200 -

# %%
# !rm -rf /content/inference_logs

# %%
# !pip install --upgrade Pillow

# %%
from PIL import Image

# Open the image
image = Image.open("/content/VIT_IDM/VIT_IDM/datasets/VITONHD/test/image/00006_00.jpg")

# Display the image
display(image)
